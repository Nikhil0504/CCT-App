# %%
import pandas as pd

# %%
def load_mapping():
    return pd.read_csv("district_mapping.csv")

# %%
load_mapping()
# Out:
#      state_id  district id             district name  \
# 0           1            3                   Nicobar
# 1           1            1  North and Middle Andaman
# 2           1            2             South Andaman
# 3           2            9                 Anantapur
# 4           2           10                  Chittoor
# ..        ...          ...                       ...
# 751        36          735         South 24 Parganas
# 752        36          736            Uttar Dinajpur
# 753        36          737            West Bardhaman
# 754        37          138                     Daman
# 755        37          139                       Diu
#
#                       state_name
# 0    Andaman and Nicobar Islands
# 1    Andaman and Nicobar Islands
# 2    Andaman and Nicobar Islands
# 3                 Andhra Pradesh
# 4                 Andhra Pradesh
# ..                           ...
# 751                  West Bengal
# 752                  West Bengal
# ...
