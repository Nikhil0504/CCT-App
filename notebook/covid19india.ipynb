# %%
import pandas as pd

# %%
url = "https://api.covid19india.org/csv/latest/case_time_series.csv"
url2 = "https://api.covid19india.org/csv/latest/states.csv"

# %%
c["Date"] = pd.to_datetime(c["Date"])
start_date = '2021-06-30'
end_date = '2021-07-01'
mask = (c['Date'] > start_date) & (c['Date'] <= end_date)
c=pd.read_csv(url2)
c.loc[mask]
# Out:
#              Date                                     State  Confirmed  \
# 17124  2021-07-01               Andaman and Nicobar Islands       7469
# 17125  2021-07-01                            Andhra Pradesh    1893354
# 17126  2021-07-01                         Arunachal Pradesh      36168
# 17127  2021-07-01                                     Assam     511153
# 17128  2021-07-01                                     Bihar     722101
# 17129  2021-07-01                                Chandigarh      61687
# 17130  2021-07-01                              Chhattisgarh     994890
# 17131  2021-07-01                                     Delhi    1434281
# 17132  2021-07-01  Dadra and Nagar Haveli and Daman and Diu      10564
# 17133  2021-07-01                                       Goa     166920
# 17134  2021-07-01                                   Gujarat     823607
# 17135  2021-07-01                          Himachal Pradesh     202290
# ...

# %%
c.head(-1)
# Out:
#              Date          State  Confirmed  Recovered  Deceased  Other  \
# 0      2020-01-30         Kerala          1          0         0      0
# 1      2020-01-30          India          1          0         0      0
# 2      2020-02-02         Kerala          2          0         0      0
# 3      2020-02-02          India          2          0         0      0
# 4      2020-02-03         Kerala          3          0         0      0
# ...           ...            ...        ...        ...       ...    ...
# 17192  2021-07-02     Tamil Nadu    2488407    2418882     32818      0
# 17193  2021-07-02        Tripura      66626      62067       680     23
# 17194  2021-07-02          India   30501721   29598189    401083  12068
# 17195  2021-07-02  Uttar Pradesh    1706380    1681208     22616      0
# 17196  2021-07-02    Uttarakhand     340488     325361      7327   5936
#
#             Tested
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# ...

# %%
pd.read_csv("https://api.covid19india.org/csv/latest/state_wise.csv")
# Out:
#                                        State  Confirmed  Recovered  Deaths  \
# 0                                      Total   30501725   29598360  401083
# 1                Andaman and Nicobar Islands       7475       7325     128
# 2                             Andhra Pradesh    1896818    1846716   12779
# 3                          Arunachal Pradesh      36572      33432     176
# 4                                      Assam     513606     483741    4604
# 5                                      Bihar     722282     710995    9594
# 6                                 Chandigarh      61700      60745     808
# 7                               Chhattisgarh     995195     976125   13450
# 8   Dadra and Nagar Haveli and Daman and Diu      10568      10490       4
# 9                                      Delhi    1434374    1408350   24983
# 10                                       Goa     167103     161867    3062
# ...
